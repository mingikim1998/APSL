# %%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# % Deedy CV/Resume
# % XeLaTeX Template
# % Version 1.0 (5/5/2014)
# %
# % This template has been downloaded from:
# % http://www.LaTeXTemplates.com
# %
# % Original author:
# % Debarghya Das (http://www.debarghyadas.com)
# % With extensive modifications by:
# % Vel (vel@latextemplates.com)
# %
# % License:
# % CC BY-NC-SA 3.0 (http://creativecommons.org/licenses/by-nc-sa/3.0/)
# %
# % Important notes:
# % This template needs to be compiled with XeLaTeX.
# %
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# \documentclass[letterpaper]{deedy-resume} % Use US Letter paper, change to a4paper for A4
#
# \begin{document}
#
# %----------------------------------------------------------------------------------------
# %	TITLE SECTION
# %----------------------------------------------------------------------------------------
#
# \lastupdated % Print the Last Updated text at the top right
#
# \namesection{Mingi}{Kim}{ % Your name profile or other web address
# \href{https://github.com/mingikim1998/APSL}{\bf https://github.com/mingikim1998/APSL} \\
# \href{https://www.linkedin.com/in/mingi-k-34ba9918b/}{\bf https://www.linkedin.com/in/mingi-k-34ba9918b/} \\
# \href{mailto:babel5165@gmail.com}{babel5165@gmail.com} | 010-5165-5610 | live:.cid.1a4300bc6da003df (skype)% Your contact information
# }
#
# %----------------------------------------------------------------------------------------
# %	LEFT COLUMN
# %----------------------------------------------------------------------------------------
#
# \begin{minipage}[t]{0.33\textwidth} % The left column takes up 33% of the text width of the page
#
# %------------------------------------------------
# % Skills
# %------------------------------------------------
#
# \section{Skills}
#
# \subsection{Language}
# English, Korean and Mandarin \\
# Business English  \\
# Korean as First language \\
# % Django \\
# Fluent Chinese Mandarin \\
#
# \sectionspace % Some white space after the section
#
# \subsection{Certificates}
# Toeic IBT 940 \\
# Toeic Speaking level 7 \\
# HSK6 \\
# % Regression \\
# % Support Vector Machines \\
# % Naive Bayes \\
# % K-Nearest Neighbors \\
# % Decision Trees \\
# % Cluster Analyses \\
# % Natural Language Processing \\
#
# \sectionspace % Some white space after the section
#
# \subsection{Software Tools}
# %Google Drive \\
# MS Office \\
# Google Drive, One Drive \\
# Presentations, Slideshows \\
# Python \\
# Tensorflow2 \\
# %Email \\
# % MS Office \\
# % Git and Github \\
# % MongoDB \\
# %Cisco Packet Tracer \\
# % \\
#
#
#
# \sectionspace % Some white space after the section
#
# %------------------------------------------------
# % Education
# %------------------------------------------------
#
# \section{Education}
#
# \subsection{Logistics}
#
# \descript{Major}
# \location{Mar 2016 - Present | Incheon}
# Asia Pacific School of Logistics \\
# Specialized in Global logistics, Business English and Supply Chain Management
# \sectionspace % Some white space after the section
#
# \subsection{Industrial Engineering}
# % \descript{| Jan 2018}
#
# \descript{Double Major}
# \location{Mar 2019 - Present | Incheon}
# Specialized in Optimization, Computer Languages and Statistics
# %Telecommunications with elective courses of Advance Statistics and Project management
# % Thesis: \href{http://scholarworks.umass.edu/cgi/viewcontent.cgi?article=1851&context=theses}{\bf The Economic Impacts of Technical Change in Carbon Capture}}
#
#
# \sectionspace % Some white space after the section
#
# %------------------------------------------------
#
# \subsection{Harbin Language Program}
# \descript{Jan 2019 - Mar 2019 | Harbin}
# Excelled in absorbing Mandarin Speaking
# \location{\\
# Finished Program with Honors}
#
# % \sectionspace % Some white space after the section
#
#
# %------------------------------------------------
# % Links
# %------------------------------------------------
#
# % \section{Links}
#
# % Github:// \href{https://github.com/SIMAABAMIR}{\bf SIMAABAMIR} \\
# % LinkedIn:// \href{https://www.linkedin.com/in/petergrayrasmussen}{\bf petergrayrasmussen} \\
# % Twitter:// \href{https://twitter.com/pgr_me}{\bf @pgr\_me} \\
#
# %------------------------------------------------
# % Volunteer
# %------------------------------------------------
#
# \section{Volunteer}
# \sectionspace % Some white space after the section
# \begin{tightitemize}
# \item Taught Chinese high-school students English and Maths for one year
# \item Organized fun activities at Korean Culture and Information Service
# \item Reported errors of foreign press for the sake of Korea's image
# \end{tightitemize}
#
# % Github:// \href{https://github.com/SIMAABAMIR}{\bf SIMAABAMIR} \\
# % LinkedIn:// \href{https://www.linkedin.com/in/petergrayrasmussen}{\bf petergrayrasmussen} \\
# % Twitter:// \href{https://twitter.com/pgr_me}{\bf @pgr\_me} \\
#
# \sectionspace % Some white space after the section
#
# %----------------------------------------------------------------------------------------
#
# \end{minipage} % The end of the left column
# \hfill
# %
# %----------------------------------------------------------------------------------------
# %	RIGHT COLUMN
# %----------------------------------------------------------------------------------------
# %
# \begin{minipage}[t]{0.66\textwidth} % The right column takes up 66% of the text width of the page
#
# %------------------------------------------------
# % Experience
# %------------------------------------------------
#
# \section{Experience}
# % MLPlus
# % service desk asst aits analyst
# % phone survey
# % tata steel
# % radio
#
# \runsubsection{Club Activities}
# \descript{| Programming }
#
# \location{June 2016 – Present | Inha University}
# \vspace{\topsep} % Hacky fix for awkward extra vertical space
# \begin{tightitemize}
# \item Building Algorithms without calling libraries.
# \item Implementing Statistics in Tensorflow2 using Python language.
# %\item Scraped, cleaned, and tokenized 2000 unique question bank as inputs to sequential model.
# %\item Trained  a deep learning model to predict types of nails used in tibial fractures with 74 percent accuracy.
# \end{tightitemize}
#
# % \location{Apr 2016 – Jun 2016 | New York, NY}
# % \vspace{\topsep} % Hacky fix for awkward extra vertical space
# % \begin{tightitemize}
# % \item Built \href{http://pgr-me.github.io/Microlending/}{\bf explanatory linear regression model} for an \href{http://playseeds.com/}{\bf NYC startup} to identify the types of people who are the most active microlenders
# % \item Scraped, cleaned, and assimilated movie box office data as inputs to \href{http://pgr-me.github.io/B-Horror/}{\bf box office revenue prediction model}
# % \item \href{http://pgr-me.github.io/Water/}{\bf Visualized univariate and multivariate clusters} of water usage, price, income, and other factors in the US using Jenks and K-Means algorithms
# % \end{tightitemize}
#
# \sectionspace % Some white space after the section
#
# \runsubsection{Military Service}
# \descript{| Administrative Specialist}
# \location{Jan 2017 – Dec 2018| Airforce Logistics Command}
# \begin{tightitemize}
# \item Managing flight schedules of Aircrafts(CN-235, C-130).
# \item Writing daily reports on number of passengers and cargoes.
# \end{tightitemize}
# \sectionspace % Some white space after the section
#
# \runsubsection{Life in Thailand}
# %\descript{| Administrative Specialist}
# \location{Feb 2011 – Jan 2016| Bangkok}
# \begin{tightitemize}
# \item Attended
# \item Writing daily reports on number of passengers and cargoes.
# \end{tightitemize}
# % \begin{tightitemize}
# % \item {\bf Mobile Financial Commerce (MFC) Market Analyses}
# % \begin{tightitemize}
# % \vspace{\topsep} % Hacky fix for awkward extra vertical space
# % \item Led quantitative analysis to develop value propositions for a multinational company seeking to enter MFC markets in several African markets
# % \item Built financial model to assess market potential and expected cash flows of a Tanzanian mobile payments startup
# % \item Authored market-sizing and forecasting section of a commercial \href{http://www.mondato.com/publications/}{\bf report} on characteristics, forecasts, and trends in MFC for several African markets
# % \end{tightitemize}
# % \end{tightitemize}
# \sectionspace % Some whitespace after the section
# %------------------------------------------------
#
# % Project
# %------------------------------------------------
#
# \section{Projects}
#
# \runsubsection{International Logistics Case Competition}
# \descript{| Jun 2016}
# \location{\bf Hongkong Logistics Association}
# \begin{tightitemize}
# %\item Developed an algorithm using Machine Learning algorithm (Random Forest) to forecast whether in the coming weeks/months the machines of a Coal Terminal require maintenance.
# \item Visited Korean Air and LG Pantos to figure out differences in logistics process.
# \item Made English presentations based on field work experience.
# \item Communicated with a number of teams and teammates from foreign countries.
#
# \end{tightitemize}
# \sectionspace % Some whitespace after the section
#
# \runsubsection{Creative Product Marketing}
# \descript{| June 2018}
# \location{\bf Aromatherapy oil vending machine}
# % \location{Oct 2011 – Jul 2012 | Nairobi, Kenya}
# \begin{tightitemize}
# \item Made a 30 minute long English presentation on a non-existent product by being creative.
# %\item Built a regression model to predict electricity usage of household using Sensors readings, internal and external environment data given in time series format.
# \item Provided audience with self-made products, leaflets and video advertisement.
# \end{tightitemize}
# \sectionspace % Some whitespace after the section
#
#
#
# % \runsubsection{Engineers Without Borders}
# % \descript{| Program Manager}
# % \location{Jun 2010 – May 2011 | Amherst, MA}
# % \begin{tightitemize}
# % \item Managed EWB-UMass Kenya program to improve water quality in western Kenya for a rural community of approximately 10,000
# % \end{tightitemize}
# \sectionspace % Some white space after the section
#
# %\runsubsection{Retail Sector Forecast}
# %\descript{| Feb - March 2018}
# %\location{\bf In collaboration with Md. Irfan Ghani, Montreal}
# %\begin{tightitemize}
# %\item Assessed the business environment for a firm which is considering an expansion into three different states using sklearn’s multivariate regression.
# %\item Interesting insights were found out such as maximum sales in December because of holidays and worst %sales in February due to paying debts.
# %\end{tightitemize}
#
# % \runsubsection{University of Massachusetts}
# % \descript{| Research Assistant}
# % \location{Aug 2009 – May 2011 | Amherst, MA}
# % \begin{tightitemize}
# % \item Modeled long-term economic impacts of technical change in carbon capture (CC) given a greenhouse gas emissions policy
# % \item Conducted sensitivity analyses of key performance drivers of CC costs to simulate the impact of technical change on CC cost
# % \end{tightitemize}
# \sectionspace % Some white space after the section
#
# %------------------------------------------------
#
# % Project
# %------------------------------------------------
#
# \section{Achievements}
# \begin{tightitemize}
# \sectionspace % Some white space after the section
# \item Ranked 1st position at Data Science competition organized by ML Plus for building a classifier model with 95\% accuracy.
# \item Recognized by the Golden Key International Honor Society for outstanding academic achievements at Concordia for being in top 15\% graduates.
# \item Merit cum Means Scholarship (2012 - 2016): Indian Govt. funded tuition and living expenses during Bachelor studies.
#
#
# \end{tightitemize}
#
# % \runsubsection{Environmental Resources Management}
# % \descript{| Staff Engineer}
# % \location{Jul 2006 – Aug 2009 | New Orleans, LA}
# % \begin{tightitemize}
# % \item Managed environmental consulting projects across multiple sectors, including energy and manufacturing
# % \end{tightitemize}
# \sectionspace % Some white space after the section
#
# %----------------------------------------------------------------------------------------
#
# \end{minipage} % The end of the right column
#
# %----------------------------------------------------------------------------------------
# %	SECOND PAGE (EXAMPLE)
# %----------------------------------------------------------------------------------------
#
# %\newpage % Start a new page
#
# %\begin{minipage}[t]{0.33\textwidth} % The left column takes up 33% of the text width of the page
#
# %\section{Example Section}
#
# %\end{minipage} % The end of the left column
# %\hfill
# %\begin{minipage}[t]{0.66\textwidth} % The right column takes up 66% of the text width of the page
#
# %\section{Example Section 2}
#
# %\end{minipage} % The end of the right column
#
# %----------------------------------------------------------------------------------------
#
# \end{document}
